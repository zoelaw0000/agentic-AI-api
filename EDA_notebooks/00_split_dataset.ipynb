# %%
import pandas as pd

# Load full dataset
df = pd.read_csv("C:/XMUM/2026.04/Advance Data Analytic/project_code/data/diabetic_flat.csv")

print("Total rows:", len(df))
df.head()
# Out:
# Total rows: 101766
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
# shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
n = len(df)

demo100 = df.iloc[:100]
demo500 = df.iloc[:500]
demo1000 = df.iloc[:1000]
demo5000 = df.iloc[:5000]

# %%
demo100.to_csv("C:/XMUM/2026.04/Advance Data Analytic/project_code/data/demo_upload/diabetic_demo100.csv", index=False)
demo500.to_csv("C:/XMUM/2026.04/Advance Data Analytic/project_code/data/demo_upload/diabetic_demo500.csv", index=False)
demo1000.to_csv("C:/XMUM/2026.04/Advance Data Analytic/project_code/data/demo_upload/diabetic_demo1000.csv", index=False)
demo5000.to_csv("C:/XMUM/2026.04/Advance Data Analytic/project_code/data/demo_upload/diabetic_demo5000.csv", index=False)
